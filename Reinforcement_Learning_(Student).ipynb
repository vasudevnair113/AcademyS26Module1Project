# %% [markdown]
# <a href="https://colab.research.google.com/github/vasudevnair113/AcademyS26Module1Project/blob/master/Reinforcement_Learning_(Student).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WELCOME TO AI ACADEMY! TODAY WE'LL DISCUSS REINFORCEMENT LEARNING. It's used by all the major tech companies, such as:
# - Amazon
# - Netflix, HBO Max, Disney+, Peacock
# - Spotify, Apple Music
# - Waymo
# - IBM, Google
# - Meta: Facebook, Instagram, Threads
#
# STOP!
#
# DON'T OPEN THE DROPDOWN UNTIL WE GET THERE. Make a copy of the notebook by going to File > Save a copy in Drive, and then edit that one!

# %% [markdown]
# ## Do not open this dropdown!

# %%
# !pip install gymnasium
# !pip install matplotlib
# !pip install numpy
# !pip install IPython

# %% [markdown]
# ## Code starts here!

# %%
#IMPORTS
import ____ as gym
# We need to randomize the values. What library should we import?
import ______
# We will deal with matrices, numbers, and linear algebra concepts. What do we need to import?
import _______
# To make graphs, we need which Python library?
import ______
from IPython.display import _______, ________

# %%
# Create the environment: 'S' is Start, 'F' is Frozen, 'H' is Hole, 'G' is Goal
env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="ansi")

#IF WE HAVE TIME, we'll use this at the end.
#env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")

# %%
#Our agent sees 16 squares (4x4) and can move in 4 directions
____ = env.observation_space.n
____ = env.action_space.n

# %%
# Initialize the "Cheat Sheet" with zeros
q_table = np.zeros((___, ____))

# %%
# Hyperparameters
learning_rate = __
gamma = ___ # High Gamma: The agent cares about the Goal!
epsilon = ___ # Exploration rate

for episode in range(__):
    state, _ = env.reset()
    done = False

    for step in range(100):
        # Decide: Explore or Exploit?
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q_table[state, :])

        new_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        # Update the Brain (Bellman Equation)
        q_table[___, _____] = q_table[_____, _____] + learning_rate * (
            reward + gamma * np.max(q_table[new_state, :]) - q_table[____, _____]
        )

        state = new_state
        if done: break

    # Reduce exploration as the agent gets smarter
    epsilon = max(0.01, epsilon * 0.995)

print("Training finished! The agent now has a map to the goal.")
# Out:
# Training finished! The agent now has a map to the goal.

# %%
state, _ = env.reset()
print("Let's see the agent reach the goal:")
for step in range(10):
    action = np.argmax(q_table[state, :])
    state, reward, done, truncated, _ = env.step(action)
    print(env.render()) # Shows the grid in text format
    if done:
        print("Goal reached!")
        break

# %%
state, _ = env.reset()
img = plt.imshow(env.render()) # Create the initial image object

for step in range(20):
    # 1. Agent chooses the best move
    action = np.argmax(q_table[state, :])
    state, reward, terminated, truncated, _ = env.step(action)

    # 2. Update the visual display
    img.set_data(env.render()) # Update the image data
    display.display(plt.gcf()) # Show current frame
    display.clear_output(wait=True) # Clear for next frame

    if terminated or truncated:
        print("Goal reached!" if reward == 1 else "Fell in a hole!")
        break

env.close()
